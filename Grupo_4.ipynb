# %% [markdown]
# <a href="https://colab.research.google.com/github/cup84/Programacion-Python/blob/main/Grupo_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import boto3

# %%
# !pip install boto3

# %% [markdown]
# # Carga de datos

# %%
type(paradas_embolsado1)
# Out:
# pandas.core.frame.DataFrame

# %%
paradas_embolsado1.shape
# Out:
# (1036, 44)

# %%
paradas_embolsado1.head()
# Out:
#    Unnamed: 0 REPORTE PARADAS DIARIAS Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 0         NaN                     NaN        NaN        NaN            NaN
# 1         NaN                     NaN        NaN        NaN            NaN
# 2         NaN                     NaN        NaN        NaN            NaN
# 3         NaN                     DIA        MES        AÑO        Sección
# 4         NaN                       1          1       2024  Embolsadura 1
#
#           Unnamed: 5 Unnamed: 6                         Unnamed: 7 Unnamed: 8  \
# 0                NaN        NaN                                NaN        NaN
# 1                NaN        NaN                                NaN        NaN
# 2                NaN        NaN                                NaN        NaN
# 3  Puesto de trabajo      UB. 2                             Equipo  FlowSheet
# 4      Embolsadura 1             ENSACADORA ROTATIVA GEV/10 PLUS 1   6G1.RP01
#
# ...

# %%
# Función iloc para hacer un filtro de los datos por posición
# Primer parámetro = "fila" Segundo parámetro = "Columna"
# Separados por ","

paradas_embolsado1 = paradas_embolsado1.iloc[3:]

# %%
paradas_embolsado1.head()
# Out:
#    Unnamed: 0 REPORTE PARADAS DIARIAS Unnamed: 2 Unnamed: 3     Unnamed: 4  \
# 3         NaN                     DIA        MES        AÑO        Sección
# 4         NaN                       1          1       2024  Embolsadura 1
# 5         NaN                       2          1       2024  Embolsadura 1
# 6         NaN                       2          1       2024  Embolsadura 1
# 7         NaN                       2          1       2024  Embolsadura 1
#
#           Unnamed: 5 Unnamed: 6                             Unnamed: 7  \
# 3  Puesto de trabajo      UB. 2                                 Equipo
# 4      Embolsadura 1                 ENSACADORA ROTATIVA GEV/10 PLUS 1
# 5      Embolsadura 1                 ENSACADORA ROTATIVA GEV/10 PLUS 1
# 6      Embolsadura 1                 ENSACADORA ROTATIVA GEV/10 PLUS 1
# 7      Embolsadura 1             APLICADOR SACOS VACIOS-INFILROT Z40 1
#
#   Unnamed: 8    Unnamed: 9  ... Unnamed: 34                       Unnamed: 35  \
# ...

# %%
cabeceras = paradas_embolsado1.iloc[0]

# %%
paradas_embolsado1.columns = cabeceras

# %%
paradas_embolsado1.head()
# Out:
# 3 NaN  DIA  MES   AÑO        Sección  Puesto de trabajo  UB. 2  \
# 3 NaN  DIA  MES   AÑO        Sección  Puesto de trabajo  UB. 2
# 4 NaN    1    1  2024  Embolsadura 1      Embolsadura 1
# 5 NaN    2    1  2024  Embolsadura 1      Embolsadura 1
# 6 NaN    2    1  2024  Embolsadura 1      Embolsadura 1
# 7 NaN    2    1  2024  Embolsadura 1      Embolsadura 1
#
# 3                                 Equipo  FlowSheet  Parada/Falla  ...  \
# 3                                 Equipo  FlowSheet  Parada/Falla  ...
# 4      ENSACADORA ROTATIVA GEV/10 PLUS 1   6G1.RP01        Parada  ...
# 5      ENSACADORA ROTATIVA GEV/10 PLUS 1   6G1.RP01        Parada  ...
# 6      ENSACADORA ROTATIVA GEV/10 PLUS 1   6G1.RP01        Parada  ...
# 7  APLICADOR SACOS VACIOS-INFILROT Z40 1   6G1.AR01        Parada  ...
#
# 3  Cod SAP 7                           Creador  Modificado Por  \
# 3  Cod SAP 7                           Creador  Modificado Por
# 4        NaN       Luis Anastacio/CPSAA/DIVCEM
# ...

# %%
paradas_embolsado1 = paradas_embolsado1.iloc[1:]

# %%
paradas_embolsado1.head()
# Out:
# 3 NaN DIA MES   AÑO        Sección Puesto de trabajo UB. 2  \
# 4 NaN   1   1  2024  Embolsadura 1     Embolsadura 1
# 5 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 6 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 7 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 8 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
#
# 3                                 Equipo FlowSheet Parada/Falla  ...  \
# 4      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 5      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 6      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 7  APLICADOR SACOS VACIOS-INFILROT Z40 1  6G1.AR01       Parada  ...
# 8      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
#
# 3 Cod SAP 7                           Creador Modificado Por  \
# 4       NaN       Luis Anastacio/CPSAA/DIVCEM
# 5       NaN  Jean Carlos Cordova/CPSAA/DIVCEM
# 6       NaN       Esteban Quispe/CPSAA/DIVCEM
# ...

# %%
paradas_embolsado1.reset_index(drop=True, inplace=True)

# %%
paradas_embolsado1.head()
# Out:
# 3 NaN DIA MES   AÑO        Sección Puesto de trabajo UB. 2  \
# 0 NaN   1   1  2024  Embolsadura 1     Embolsadura 1
# 1 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 2 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 3 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
# 4 NaN   2   1  2024  Embolsadura 1     Embolsadura 1
#
# 3                                 Equipo FlowSheet Parada/Falla  ...  \
# 0      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 1      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 2      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
# 3  APLICADOR SACOS VACIOS-INFILROT Z40 1  6G1.AR01       Parada  ...
# 4      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada  ...
#
# 3 Cod SAP 7                           Creador Modificado Por  \
# 0       NaN       Luis Anastacio/CPSAA/DIVCEM
# 1       NaN  Jean Carlos Cordova/CPSAA/DIVCEM
# 2       NaN       Esteban Quispe/CPSAA/DIVCEM
# ...

# %%
paradas_embolsado1.dtypes
# Out:
# 3
# NaN                  float64
# DIA                   object
# MES                   object
# AÑO                   object
# Sección               object
# Puesto de trabajo     object
# UB. 2                 object
# Equipo                object
# FlowSheet             object
# Parada/Falla          object
# Tipo                  object
# Origen                object
# Clase                 object
# Sub Clase             object
# Causa                 object
# Hora Inicio           object
# Fecha Fin             object
# Hora Fin              object
# Tiempo Min            object
# COSTO REP.            object
# COSTO LC              object
# TOTAL COSTO           object
# Descripción           object
# NaN                  float64
# NaN                  float64
# NaN                  float64
# NaN                  float64
# NaN                  float64
# Cod SAP 1             object
# Cod SAP 2             object
# Cod SAP 3             object
# Cod SAP 4             object
# ...

# %%
# Eliminando las columnas totalmente vacías
paradas_embolsado1 = paradas_embolsado1.dropna(axis = 1,how= "all")

# %%
paradas_embolsado1.dtypes
# Out:
# 3
# DIA                  object
# MES                  object
# AÑO                  object
# Sección              object
# Puesto de trabajo    object
# UB. 2                object
# Equipo               object
# FlowSheet            object
# Parada/Falla         object
# Tipo                 object
# Origen               object
# Clase                object
# Sub Clase            object
# Causa                object
# Hora Inicio          object
# Fecha Fin            object
# Hora Fin             object
# Tiempo Min           object
# COSTO REP.           object
# COSTO LC             object
# TOTAL COSTO          object
# Descripción          object
# Cod SAP 1            object
# Cod SAP 2            object
# Creador              object
# Modificado Por       object
# Observaciones        object
# Fecha Inicio         object
# dtype: object

# %% [markdown]
# # Tarea : Leer los 3 archivos restantes

# %%
def limpieza_tabla(tabla):
  tabla = tabla.iloc[3:]
  cabeceras = tabla.iloc[0]
  tabla.columns = cabeceras
  tabla = tabla.iloc[1:]
  tabla.reset_index(drop=True, inplace=True)
  tabla = tabla.dropna(axis = 1,how= "all")
  return tabla

# %%
paradas_embolsado1 = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Embolsado1 2023-2024.xlsx")
paradas_embolsado2 = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Embolsado2 2023-2024.xlsx")
paradas_horno = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Horno 2023-2024.xlsx")
paradas_molino = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Molino de Cemento 2023-2024.xlsx")

# %%
paradas_embolsado1 = limpieza_tabla(paradas_embolsado1)
paradas_embolsado2 = limpieza_tabla(paradas_embolsado2)
paradas_horno = limpieza_tabla(paradas_horno)
paradas_molino = limpieza_tabla(paradas_molino)

# %% [markdown]
# #Análisis paradas Embolsado 1

# %%
paradas_embolsado1.head()
# Out:
# 3 DIA MES   AÑO        Sección Puesto de trabajo UB. 2  \
# 0   1   1  2024  Embolsadura 1     Embolsadura 1
# 1   2   1  2024  Embolsadura 1     Embolsadura 1
# 2   2   1  2024  Embolsadura 1     Embolsadura 1
# 3   2   1  2024  Embolsadura 1     Embolsadura 1
# 4   2   1  2024  Embolsadura 1     Embolsadura 1
#
# 3                                 Equipo FlowSheet Parada/Falla  \
# 0      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada
# 1      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada
# 2      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada
# 3  APLICADOR SACOS VACIOS-INFILROT Z40 1  6G1.AR01       Parada
# 4      ENSACADORA ROTATIVA GEV/10 PLUS 1  6G1.RP01       Parada
#
# 3                   Tipo   ... COSTO REP. COSTO LC TOTAL COSTO  \
# 0     Paradas Programadas  ...          0        0           0
# 1     Paradas Programadas  ...          0        0           0
# 2     Paradas Programadas  ...          0        0           0
# ...

# %%
paradas_embolsado1 = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Embolsado1 2023-2024.xlsx")

# %%
paradas_embolsado1.shape
# Out:
# (1036, 44)

# %%
paradas_embolsado1.dtypes
# Out:
# Unnamed: 0                 float64
# REPORTE PARADAS DIARIAS     object
# Unnamed: 2                  object
# Unnamed: 3                  object
# Unnamed: 4                  object
# Unnamed: 5                  object
# Unnamed: 6                  object
# Unnamed: 7                  object
# Unnamed: 8                  object
# Unnamed: 9                  object
# Unnamed: 10                 object
# Unnamed: 11                 object
# Unnamed: 12                 object
# Unnamed: 13                 object
# Unnamed: 14                 object
# Unnamed: 15                 object
# Unnamed: 16                 object
# Unnamed: 17                 object
# Unnamed: 18                 object
# Unnamed: 19                 object
# Unnamed: 20                 object
# Unnamed: 21                 object
# Unnamed: 22                 object
# Unnamed: 23                float64
# Unnamed: 24                float64
# Unnamed: 25                float64
# Unnamed: 26                float64
# ...

# %%
variables_categoricas = ['MES', 'AÑO','Sección', 'Puesto de trabajo', 'UB. 2', 'Equipo',
       'FlowSheet', 'Parada/Falla', 'Tipo ', 'Origen ', 'Clase ', 'Sub Clase ',
       'Causa']

# %%
for i in variables_categoricas:
  print("-----------------------")
  print(paradas_embolsado1[i].value_counts())
# Out:
# -----------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MES'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Analizando columnas con valores nulos
paradas_embolsado1.isnull().sum()
# Out:
# Unnamed: 0                 1036
# REPORTE PARADAS DIARIAS       3
# Unnamed: 2                    3
# Unnamed: 3                    3
# Unnamed: 4                    3
# Unnamed: 5                    3
# Unnamed: 6                    3
# Unnamed: 7                    3
# Unnamed: 8                    3
# Unnamed: 9                    3
# Unnamed: 10                   3
# Unnamed: 11                   3
# Unnamed: 12                   3
# Unnamed: 13                   3
# Unnamed: 14                   3
# Unnamed: 15                   3
# Unnamed: 16                   3
# Unnamed: 17                   3
# Unnamed: 18                   3
# Unnamed: 19                   3
# Unnamed: 20                   3
# Unnamed: 21                   3
# Unnamed: 22                   3
# Unnamed: 23                1036
# Unnamed: 24                1036
# Unnamed: 25                1036
# Unnamed: 26                1036
# Unnamed: 27                1036
# Unnamed: 28                   3
# ...

# %%
#Eliminando columnas con valores totalmente nulos
paradas_embolsado1 = paradas_embolsado1.drop("UB. 2",axis=1)
paradas_embolsado1.drop("Causa",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-8f10b62e756f> in <cell line: 2>()
#       1 #Eliminando columnas con valores totalmente nulos
# ----> 2 paradas_embolsado1 = paradas_embolsado1.drop("UB. 2",axis=1)
#       3 paradas_embolsado1.drop("Causa",axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# ...

# %%
#Analizando filas con valores nulos
paradas_embolsado1.isnull().all(axis=1).sum()

# %%
paradas_embolsado1["Fecha Fin"] = pd.to_datetime(paradas_embolsado1["Fecha Fin"],format="%d/%m/%Y")
paradas_embolsado1["Fecha Inicio"] = pd.to_datetime(paradas_embolsado1["Fecha Inicio"],format="%d/%m/%Y")

# %%
paradas_embolsado1["Hora Inicio"]
# Out:
# 0       07:00:00
# 1       07:00:00
# 2       15:00:00
# 3       18:25:00
# 4       19:12:00
#           ...
# 1027    16:54:00
# 1028    17:03:00
# 1029    18:47:00
# 1030    22:11:00
# 1031    22:45:00
# Name: Hora Inicio, Length: 1032, dtype: object

# %%
paradas_embolsado1["Hora Inicio"] = pd.to_datetime(paradas_embolsado1["Hora Inicio"],format="%H:%M").dt.time

# %%
paradas_embolsado1["Hora Fin"] = pd.to_datetime(paradas_embolsado1["Hora Fin"],format="%H:%M").dt.time

# %%
paradas_embolsado1.dtypes
# Out:
# 3
# DIA                  object
# MES                  object
# AÑO                  object
# Sección              object
# Puesto de trabajo    object
# UB. 2                object
# Equipo               object
# FlowSheet            object
# Parada/Falla         object
# Tipo                 object
# Origen               object
# Clase                object
# Sub Clase            object
# Causa                object
# Hora Inicio          object
# Fecha Fin            object
# Hora Fin             object
# Tiempo Min            int64
# COSTO REP.           object
# COSTO LC             object
# TOTAL COSTO          object
# Descripción          object
# Cod SAP 1            object
# Cod SAP 2            object
# Creador              object
# Modificado Por       object
# Observaciones        object
# Fecha Inicio         object
# dtype: object

# %%
paradas_embolsado1["Tiempo Min"] = pd.to_numeric(paradas_embolsado1["Tiempo Min"])

# %%
paradas_embolsado1.columns
# Out:
# Index(['DIA', 'MES', 'AÑO', 'Sección', 'Puesto de trabajo', 'UB. 2', 'Equipo',
#        'FlowSheet', 'Parada/Falla', 'Tipo ', 'Origen ', 'Clase ', 'Sub Clase ',
#        'Causa', 'Hora Inicio', 'Fecha Fin', 'Hora Fin', 'Tiempo Min',
#        'COSTO REP.', 'COSTO LC', 'TOTAL COSTO', 'Descripción', 'Cod SAP 1',
#        'Cod SAP 2', 'Creador', 'Modificado Por', 'Observaciones',
#        'Fecha Inicio'],
#       dtype='object', name=3)

# %%
paradas_embolsado1["Puesto de trabajo"].value_counts()
# Out:
# Puesto de trabajo
# Embolsadura 1    1032
# Name: count, dtype: int64

# %%
paradas_embolsado1["Sección"].value_counts()
# Out:
# Sección
# Embolsadura 1    1032
# Name: count, dtype: int64

# %%
paradas_embolsado1["UB. 2"].value_counts()
# Out:
# UB. 2
#      1032
# Name: count, dtype: int64

# %% [markdown]
# Pendientes:
# - Mejorar la función limpieza_tabla
# - Crear función convertir variable objeto a fecha
# - Crear función convertir variable objeto a numérico
# - Análisis del resto de tablas.
#
# PARADAS EMBOLSADO 2: Vladimir y Sebastian
# PARADAS HORNO: CARLOS Y JORGE
# PARADAS MOLINO: CUPER Y JOHN

# %%
def limpieza_tabla(tabla):
  tabla = tabla.iloc[3:]
  cabeceras = tabla.iloc[0]
  tabla.columns = cabeceras
  tabla = tabla.iloc[1:]
  tabla.reset_index(drop=True, inplace=True)
  tabla = tabla.dropna(axis = 1,how= "all")
  return tabla

# %%
paradas_embolsado1 = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Embolsado1 2023-2024.xlsx")
paradas_embolsado2 = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Embolsado2 2023-2024.xlsx")
paradas_horno = pd.read_excel("/content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Horno 2023-2024.xlsx")
paradas_molino = pd.read_excel("//content/drive/MyDrive/2024 - Grupo 4 -Trabajo Grupal - Python (UTEC)/Segundo Entregable/Datos/Paradas Molino de Cemento 2023-2024.xlsx")

# %%
paradas_embolsado1 = limpieza_tabla(paradas_embolsado1)
paradas_embolsado2 = limpieza_tabla(paradas_embolsado2)
paradas_horno = limpieza_tabla(paradas_horno)
paradas_molino = limpieza_tabla(paradas_molino)

# %% [markdown]
# Analisis Paradas Molino Cemento

# %%
paradas_molino.shape
# Out:
# (769, 28)

# %%
paradas_molino.dtypes
# Out:
# 3
# DIA                  object
# MES                  object
# AÑO                  object
# Sección              object
# Puesto de trabajo    object
# Equipo               object
# FlowSheet            object
# Parada/Falla         object
# Tipo                 object
# Origen               object
# Clase                object
# Sub Clase            object
# Hora Inicio          object
# Fecha Fin            object
# Hora Fin             object
# Tiempo Min            int64
# COSTO REP.           object
# COSTO LC             object
# TOTAL COSTO          object
# Descripción          object
# Cod SAP 1            object
# Cod SAP 2            object
# Creador              object
# Modificado Por       object
# Observaciones        object
# Fecha Inicio         object
# dtype: object

# %%
variables_categoricas = ['MES', 'AÑO','Sección', 'Puesto de trabajo', 'UB. 2', 'Equipo',
       'FlowSheet', 'Parada/Falla', 'Tipo ', 'Origen ', 'Clase ', 'Sub Clase ',
       'Causa']

# %%
for i in variables_categoricas:
  print("-----------------------")
  if i in paradas_molino.columns:
   print (paradas_molino[i].value_counts())
  else:
    print(f"Column '{i}' not found in DataFrame.")
# Out:
# -----------------------
# MES
# 3     126
# 4      86
# 2      82
# 5      75
# 1      70
# 6      60
# 7      54
# 10     51
# 8      49
# 12     45
# 11     39
# 9      32
# Name: count, dtype: int64
# -----------------------
# AÑO
# 2023    565
# 2024    204
# Name: count, dtype: int64
# -----------------------
# Sección
# Molino de Cemento 1    769
# Name: count, dtype: int64
# -----------------------
# Puesto de trabajo
# Molino De Cemento 1    769
# Name: count, dtype: int64
# -----------------------
# Column 'UB. 2' not found in DataFrame.
# -----------------------
# Equipo
# MOLINO DE CEMENTO                 761
#                                     5
# ACUMULADORES DE PISTON 1            1
# GABINETE DE SISTEMA HIDRAULICO      1
# MOTOR BOMBA DE BAJA PRESION         1
# Name: count, dtype: int64
# -----------------------
# FlowSheet
# 5E1.RM01                761
#                           5
# 5F1.RM01.HYS01.P2001      1
# 5F1.RM01.HYS02.G2101      1
# ...

# %%
#Analizando columnas con valores nulos
paradas_molino.isnull().sum()
# Out:
# 3
# DIA                  0
# MES                  0
# AÑO                  0
# Sección              0
# Puesto de trabajo    0
# Equipo               0
# FlowSheet            0
# Parada/Falla         0
# Tipo                 0
# Origen               0
# Clase                0
# Sub Clase            0
# Hora Inicio          0
# Fecha Fin            0
# Hora Fin             0
# Tiempo Min           0
# COSTO REP.           0
# COSTO LC             0
# TOTAL COSTO          0
# Descripción          0
# Cod SAP 1            0
# Cod SAP 2            0
# Creador              0
# Modificado Por       0
# Observaciones        0
# Fecha Inicio         0
# dtype: int64

# %%
#eliminando columnas con valores totalmente nulos
paradas_molino = paradas_molino.drop("UB. 2",axis=1)
paradas_molino.drop("Causa",axis=1,inplace=True)

# %%
#analizando filas con valores totalmente nulos
paradas_molino.isnull().all(axis=1).sum()
# Out:
# 0

# %%
paradas_molino["Fecha Fin"] = pd.to_datetime(paradas_molino["Fecha Fin"],format="%d/%m/%Y")
paradas_molino["Fecha Inicio"] = pd.to_datetime(paradas_molino["Fecha Inicio"],format="%d/%m/%Y")

# %%
paradas_molino["Tiempo Min"] = pd.to_numeric(paradas_molino["Tiempo Min"])

# %%
paradas_molino.columns
# Out:
# Index(['DIA', 'MES', 'AÑO', 'Sección', 'Puesto de trabajo', 'UB. 2', 'Equipo',
#        'FlowSheet', 'Parada/Falla', 'Tipo ', 'Origen ', 'Clase ', 'Sub Clase ',
#        'Causa', 'Hora Inicio', 'Fecha Fin', 'Hora Fin', 'Tiempo Min',
#        'COSTO REP.', 'COSTO LC', 'TOTAL COSTO', 'Descripción', 'Cod SAP 1',
#        'Cod SAP 2', 'Creador', 'Modificado Por', 'Observaciones',
#        'Fecha Inicio'],
#       dtype='object', name=3)

# %%
paradas_molino["Puesto de trabajo"].value_counts()
# Out:
# Puesto de trabajo
# Molino De Cemento 1    769
# Name: count, dtype: int64

# %%
paradas_molino["Sección"].value_counts()
# Out:
# Sección
# Molino de Cemento 1    769
# Name: count, dtype: int64

# %%
paradas_molino.head()
# Out:
# 3 DIA MES   AÑO              Sección    Puesto de trabajo     UB. 2  \
# 0   1   1  2023  Molino de Cemento 1  Molino De Cemento 1  MOLIENDA
# 1   2   1  2023  Molino de Cemento 1  Molino De Cemento 1  MOLIENDA
# 2   3   1  2023  Molino de Cemento 1  Molino De Cemento 1  MOLIENDA
# 3   4   1  2023  Molino de Cemento 1  Molino De Cemento 1  MOLIENDA
# 4   5   1  2023  Molino de Cemento 1  Molino De Cemento 1  MOLIENDA
#
# 3             Equipo FlowSheet Parada/Falla                Tipo   ...  \
# 0  MOLINO DE CEMENTO  5E1.RM01       Parada  Paradas Programadas  ...
# 1  MOLINO DE CEMENTO  5E1.RM01       Parada  Paradas Programadas  ...
# 2  MOLINO DE CEMENTO  5E1.RM01       Parada  Paradas Programadas  ...
# 3  MOLINO DE CEMENTO  5E1.RM01       Parada  Paradas Programadas  ...
# 4  MOLINO DE CEMENTO  5E1.RM01       Parada  Paradas Programadas  ...
#
# 3 COSTO REP. COSTO LC TOTAL COSTO         Descripción Cod SAP 1 Cod SAP 2  \
# ...

# %%
paradas_molino["Fecha Fin"] = pd.to_datetime(paradas_molino["Fecha Fin"],format="%d/%m/%Y")
paradas_molino["Fecha Inicio"] = pd.to_datetime(paradas_molino["Fecha Inicio"],format="%d/%m/%Y")

# %%
paradas_embolsado1["Hora Inicio"]
# Out:
# 0       07:00:00
# 1       07:00:00
# 2       15:00:00
# 3       18:25:00
# 4       19:12:00
#           ...
# 1027    16:54:00
# 1028    17:03:00
# 1029    18:47:00
# 1030    22:11:00
# 1031    22:45:00
# Name: Hora Inicio, Length: 1032, dtype: object
